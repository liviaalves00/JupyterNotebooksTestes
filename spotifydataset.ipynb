# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
spo_dt = pd.read_csv('/home/dinte/testesconda/spotify/spotify_tracks.csv')

# %%
spo_dt.describe()
# Out:
#         popularity   duration_ms
# count  6300.000000  6.300000e+03
# mean     30.754762  2.028477e+05
# std      19.948991  1.210299e+05
# min       0.000000  3.006000e+04
# 25%      16.000000  1.476870e+05
# 50%      29.000000  1.916070e+05
# 75%      45.000000  2.369625e+05
# max      90.000000  3.601658e+06

# %%
spo_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6300 entries, 0 to 6299
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6300 non-null   object
#  1   name         6300 non-null   object
#  2   genre        6300 non-null   object
#  3   artists      6300 non-null   object
#  4   album        6300 non-null   object
#  5   popularity   6300 non-null   int64
#  6   duration_ms  6300 non-null   int64
#  7   explicit     6300 non-null   bool
# dtypes: bool(1), int64(2), object(5)
# memory usage: 350.8+ KB

# %%
spo_dt.plot()
# Out:
# <Axes: >

# %%
artists =spo_dt['artists']
display(artists)
# Out:
# 0                                    Billy Raffoul
# 1                                    Billy Raffoul
# 2                    Molly Hocking, Bailey Rushlow
# 3                                The Goo Goo Dolls
# 4                    Guus Dielissen, Casper Esmann
#                            ...
# 6295                            Future World Music
# 6296    Putumayo, Marianne Perrudin, Thomas Artaud
# 6297                               Joseph Tawadros
# 6298                            Future World Music
# 6299                    Putumayo, Giacomo Lariccia
# Name: artists, Length: 6300, dtype: object

# %%
art_music = spo_dt[['artists', 'name']]
display(art_music)
# Out:
#                                          artists  \
# 0                                  Billy Raffoul
# 1                                  Billy Raffoul
# 2                  Molly Hocking, Bailey Rushlow
# 3                              The Goo Goo Dolls
# 4                  Guus Dielissen, Casper Esmann
# ...                                          ...
# 6295                          Future World Music
# 6296  Putumayo, Marianne Perrudin, Thomas Artaud
# 6297                             Joseph Tawadros
# 6298                          Future World Music
# 6299                  Putumayo, Giacomo Lariccia
#
#                                                name
# 0                                          Acoustic
# 1                                          Acoustic
# 2                     Here Comes the Sun - Acoustic
# 3                                       Acoustic #3
# 4     My Love Mine All Mine - Acoustic Instrumental
# ...                                             ...
# ...

# %%
spo_dt.drop_duplicates()
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6295  4uveHSzaz8YEbTF9j6QlCI                             Voyage to Atlantis
# 6296  4u15cjyziW2Ewn5Ek3082l                                       L'Oiseau
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
#
# ...

# %%
genre_acoustic = spo_dt.loc[spo_dt['genre'] == 'acoustic']
display(genre_acoustic)
# Out:
#                         id                                           name  \
# 0   7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1   1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2   6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3   1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4   5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# 5   742ZnC1OgUGIScdzXEy5ui                                       Acoustic
# 6   3vpJdk93GzerZnlou6Ua0z                    Beautiful Things - Acoustic
# 7   42qGA2116mkpSAaxzQfjEf                                      Landslide
# 8   0OHHcoyrWnkVukc911UeZd                                       Acoustic
# 9   64zEnxASl3epPAIH4MsmSw                     Acoustic Energy Vibrations
# 10  1okbqCnEzl9GUddnjNkb19                                    Little Lies
# 11  5Ix5RkjIO1r3gL0NH2KpqK                                       Acoustic
# ...

# %%
all_genres = spo_dt['genre'].unique()

for genre in all_genres:
    print(genre)
# Out:
# acoustic
# afrobeat
# alt-rock
# alternative
# ambient
# anime
# black-metal
# bluegrass
# blues
# bossanova
# brazil
# breakbeat
# british
# cantopop
# chicago-house
# children
# chill
# classical
# club
# comedy
# country
# dance
# dancehall
# death-metal
# deep-house
# detroit-techno
# disco
# disney
# drum-and-bass
# dub
# dubstep
# edm
# electro
# electronic
# emo
# folk
# forro
# french
# funk
# garage
# german
# gospel
# goth
# grindcore
# groove
# grunge
# guitar
# happy
# hard-rock
# hardcore
# hardstyle
# heavy-metal
# hip-hop
# holidays
# honky-tonk
# house
# idm
# indian
# indie
# indie-pop
# industrial
# iranian
# j-dance
# j-idol
# j-pop
# j-rock
# jazz
# k-pop
# kids
# latin
# latino
# malay
# mandopop
# metal
# metal-misc
# metalcore
# minimal-techno
# movies
# mpb
# new-age
# new-release
# opera
# pagode
# party
# philippines-opm
# piano
# pop
# pop-film
# post-dubstep
# power-pop
# progressive-house
# psych-rock
# punk
# punk-rock
# r-n-b
# rainy-day
# reggae
# ...

# %%
genre_series = pd.Series(spo_dt['genre'].unique())
genre_counts = genre_series.count()
print('qtd total de generos:', genre_counts, '\n')

display(genre_series)
# Out:
# qtd total de generos: 126
# 0         acoustic
# 1         afrobeat
# 2         alt-rock
# 3      alternative
# 4          ambient
#           ...
# 121         trance
# 122       trip-hop
# 123        turkish
# 124       work-out
# 125    world-music
# Length: 126, dtype: object

# %%
artists_series = pd.Series(spo_dt['artists'].unique())
artists_count = artists_series.count()
print('qtd total artistas:', artists_count, '\n')
display(artists_series)
# Out:
# qtd total artistas: 4651
# 0                                    Billy Raffoul
# 1                    Molly Hocking, Bailey Rushlow
# 2                                The Goo Goo Dolls
# 3                    Guus Dielissen, Casper Esmann
# 4                               Ling tosite sigure
#                            ...
# 4646                            Drums Of The World
# 4647                              Flute Relaxation
# 4648                           World Music Atelier
# 4649    Putumayo, Marianne Perrudin, Thomas Artaud
# 4650                    Putumayo, Giacomo Lariccia
# Length: 4651, dtype: object

# %%
genre_series = pd.Series(spo_dt['genre'])
genre_counts = genre_series.value_counts()

def maior_genero_qtd(genre_counts):
    if genre_counts.nunique() == 1:
        return 'valores iguais'
    else:
        max_genre = genre_counts.idxmax()
        max_count = genre_counts.max()
        return max_genre, max_count

resultado = maior_genero_qtd(genre_counts)
print(resultado)
# Out:
# valores iguais

# %%
maior_duracao = spo_dt['duration_ms'].max()
print(maior_duracao)
# Out:
# 3601658

# %%
mais_popular = spo_dt['popularity'].max()
print(mais_popular)
display(spo_dt['popularity'].iloc[90])
# Out:
# 90
# 0

# %%
spo_dt.iloc[0]
# Out:
# id             7kr3xZk4yb3YSZ4VFtg2Qt
# name                         Acoustic
# genre                        acoustic
# artists                 Billy Raffoul
# album                            1975
# popularity                         58
# duration_ms                    172199
# explicit                        False
# Name: 0, dtype: object

# %% [markdown]
# ----------------------------------------------------------------

# %% [markdown]
# EXERCÍCIOS

# %% [markdown]
# Seleção e Indexação:
#
# Selecione uma coluna específica do DataFrame.
#
# Selecione várias colunas do DataFrame.
#
# Selecione linhas específicas com base em condições.

# %%
#Selecione uma coluna específica do DataFrame.

coluna_especifica = spo_dt['album']
print(coluna_especifica)
# Out:
# 0                                                1975
# 1                             A Few More Hours at YYZ
# 2                       Here Comes the Sun (Acoustic)
# 3                                   Dizzy up the Girl
# 4       My Love Mine All Mine (Acoustic Instrumental)
#                             ...
# 6295                               Reign of Vengeance
# 6296                    Global Relaxation by Putumayo
# 6297                                      World Music
# 6298                                           Behold
# 6299                        World Party 5 by Putumayo
# Name: album, Length: 6300, dtype: object

# %%
#Selecione várias colunas do DataFrame.

varias_colunas =  spo_dt[['album', 'name', 'id']]
display(varias_colunas)
# Out:
#                                               album  \
# 0                                              1975
# 1                           A Few More Hours at YYZ
# 2                     Here Comes the Sun (Acoustic)
# 3                                 Dizzy up the Girl
# 4     My Love Mine All Mine (Acoustic Instrumental)
# ...                                             ...
# 6295                             Reign of Vengeance
# 6296                  Global Relaxation by Putumayo
# 6297                                    World Music
# 6298                                         Behold
# 6299                      World Party 5 by Putumayo
#
#                                                name                      id
# 0                                          Acoustic  7kr3xZk4yb3YSZ4VFtg2Qt
# 1                                          Acoustic  1kJygfS4eoVziBBI93MSYp
# 2                     Here Comes the Sun - Acoustic  6lynns69p4zTCRxmmiSY1x
# ...

# %%
#albuns que comecçam com a letra "w" ou "a"
albuns_w = spo_dt[spo_dt['album'].str.startswith('W')]
albuns_a = spo_dt[spo_dt['album'].str.startswith('A')]
display(albuns_w )
# Out:
#                           id                                     name  \
# 21    5y788ya4NvwhBznoDIcXwK  The Sound of Silence - Acoustic Version
# 24    0ElpbbncWT9aS7mgoqEHbQ               Where's My Love - Acoustic
# 37    35gFVyd6BvCmjpyuueMRkQ            We Built This City - Acoustic
# 55    5ZtK8XAVnoaGdBXZWCEVCY                        Lonely At The Top
# 83    0Q1bMs3xLQiDEeaneehdxv                                 Remember
# ...                      ...                                      ...
# 6282  33oO1bd2xwATCFcGWamjYg                            Dance Rhythms
# 6290  5X7XCxqnCPmRFJmMdpae2H                   Cherokee Pow Wow Drums
# 6293  6wyWHg3QwEbEloYVKjaHcp                  West African Drum Music
# 6297  56pHPaTeX2O9aVmTFYS8hV                             The Daintree
# 6299  3ry0f8ybk8upUBIk8unvmF                          Fiore d'inverno
#
#             genre                     artists  \
# 21       acoustic           Simon & Garfunkel
# ...

# %% [markdown]
# -----------------------------------------------------------------------

# %% [markdown]
# Manipulação de Dados:
#
# Adicione uma nova coluna ao DataFrame com base em cálculos ou operações em colunas existentes.
#
# Remova uma coluna do DataFrame.
#
# Altere o nome de uma coluna.

# %%
#Altere o nome de uma coluna.
spo_dt = spo_dt.rename(columns={'popularity': 'popularidade'})
display(spo_dt)
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6295  4uveHSzaz8YEbTF9j6QlCI                             Voyage to Atlantis
# 6296  4u15cjyziW2Ewn5Ek3082l                                       L'Oiseau
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
#
# ...

# %%
#Remova uma coluna do DataFrame.
spo_dt = spo_dt.drop('popularidade', axis=1)
display(spo_dt)
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6295  4uveHSzaz8YEbTF9j6QlCI                             Voyage to Atlantis
# 6296  4u15cjyziW2Ewn5Ek3082l                                       L'Oiseau
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
#
# ...

# %% [markdown]
# ---------------------------------------------------

# %% [markdown]
# Agregação e Estatísticas:
#
# Calcule estatísticas descritivas (média, desvio padrão, máximo, mínimo) para uma coluna.
#
# Agrupe os dados por uma coluna e calcule estatísticas para cada grupo.
#
# Calcule contagens ou frequências de valores únicos em uma coluna.

# %%
media = spo_dt[['popularity']].median()
print(media)
# Out:
# popularity    29.0
# dtype: float64

# %%
max = spo_dt[['popularity']].max()
print(max)
# Out:
# popularity    90
# dtype: int64

# %%
min = spo_dt[['popularity']].min()
print(min)
# Out:
# popularity    0
# dtype: int64

# %%
dp = np.std(spo_dt[['popularity']])
print(dp)
# Out:
# popularity    19.947407
# dtype: float64
# /home/dinte/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %% [markdown]
# ------------------------------------------------------------------------------

# %% [markdown]
# Ordenação e Filtragem:
#
# Ordene o DataFrame com base em uma coluna específica em ordem crescente e decrescente.
#
# Filtre o DataFrame para mostrar apenas linhas que atendem a certos critérios (por exemplo, valores maiores que um determinado número).

# %%
asc = spo_dt.sort_values('duration_ms', ascending=False)
display(asc)
# Out:
#                           id                                 name       genre  \
# 50    6JZcfM5vr5O0KeGIAWiydu                Afrobeat 2023 Mixtape    afrobeat
# 1690  0hENAKSpfMW5th2cYqJl6r                           Electronic  electronic
# 3039  4w8ma2aeiZvknYIJQdXbNt  Industrial Fan (1 Hour White Noise)  industrial
# 60    2WRQhgXftM1G0NIXr7jNmc         Afrobeats Mix Flight OSO 149    afrobeat
# 4898  6TCnFt6gFNGYxcoDsPwrdA                   Reggaeton 2024 Mix   reggaeton
# ...                      ...                                  ...         ...
# 5741  5UktsKDIBfKOJsCpGFFkd4                         El Día - Day     spanish
# 206   3GOLdD4ay0GxLazBZlLlHM                              Ambient     ambient
# 5363  3raXh0ZKJ5sW0Rldq2y2lj          Jeopardy Main Tv Show Theme  show-tunes
# 1774  0aGlC7ndhKHJINaaT2QWSY                                 Folk        folk
# 5088  6RncZITxpMOczqggjZR1g4                           Rockabilly  rockabilly
#
# ...

# %%
desc = spo_dt.sort_values('duration_ms', ascending=True)
display(desc)
# Out:
#                           id                                 name       genre  \
# 5088  6RncZITxpMOczqggjZR1g4                           Rockabilly  rockabilly
# 1774  0aGlC7ndhKHJINaaT2QWSY                                 Folk        folk
# 5363  3raXh0ZKJ5sW0Rldq2y2lj          Jeopardy Main Tv Show Theme  show-tunes
# 206   3GOLdD4ay0GxLazBZlLlHM                              Ambient     ambient
# 5741  5UktsKDIBfKOJsCpGFFkd4                         El Día - Day     spanish
# ...                      ...                                  ...         ...
# 4898  6TCnFt6gFNGYxcoDsPwrdA                   Reggaeton 2024 Mix   reggaeton
# 60    2WRQhgXftM1G0NIXr7jNmc         Afrobeats Mix Flight OSO 149    afrobeat
# 3039  4w8ma2aeiZvknYIJQdXbNt  Industrial Fan (1 Hour White Noise)  industrial
# 1690  0hENAKSpfMW5th2cYqJl6r                           Electronic  electronic
# 50    6JZcfM5vr5O0KeGIAWiydu                Afrobeat 2023 Mixtape    afrobeat
#
# ...

# %%
asc = spo_dt.sort_values('popularity', ascending=False)
display(asc)
# Out:
#                           id                                            name  \
# 1567  2HYFX63wP3otVIvopRS99Z                                         Houdini
# 5540  0zirWZTcXBBwGsevrsIpvT         Clean Baby Sleep White Noise (Loopable)
# 4746  7iabz12vAuVQYyekFIWJxD                      BAND4BAND (feat. Lil Baby)
# 2797  4Dvkj6JhhA12EX05fT7y2e                                       As It Was
# 3158  7CyPwkp0oE8Ro9Dd5CUDjW  One Of The Girls (with JENNIE, Lily Rose Depp)
# ...                      ...                                             ...
# 734   4dHaDWK76Pas6huFoMHsnh                           Afterparty Connection
# 707   7zpE1rYahyF6KiXUjm1YR2                                  Power Flexible
# 4006  0g7aNjEv8BjXio224tHyM1                                    New Releases
# 4658  0MhObPKLKVQnwIe0907l8Y                                       Punk-Rock
# 3955  63fbVOhOhTsRYrlXfIqTE2                                         New-Age
#
# ...

# %%
desc = spo_dt.sort_values('popularity', ascending=True)
display(desc)
# Out:
#                           id                                            name  \
# 4479  2XLkh3CxRjatfsDgHwIEsM                                       Power Pop
# 4548  5KANR3BIyuRtoWybs47c83                             Breakbeat Uplifting
# 3058  5DdX47F5335Uz5e4CGAk3L                                         Iranian
# 2546  3N3PYCFDTtHg9oA2e0bqTT                                       Hardstyle
# 2156  1kewnvXts98PACx0oAU4i3                                       GrindCore
# ...                      ...                                             ...
# 2797  4Dvkj6JhhA12EX05fT7y2e                                       As It Was
# 3158  7CyPwkp0oE8Ro9Dd5CUDjW  One Of The Girls (with JENNIE, Lily Rose Depp)
# 4746  7iabz12vAuVQYyekFIWJxD                      BAND4BAND (feat. Lil Baby)
# 5540  0zirWZTcXBBwGsevrsIpvT         Clean Baby Sleep White Noise (Loopable)
# 1567  2HYFX63wP3otVIvopRS99Z                                         Houdini
#
# ...

# %%
#Filtre o DataFrame para mostrar apenas linhas que atendem a certos critérios (por exemplo, valores maiores que um determinado número).

maiores_que_50 = spo_dt.loc[spo_dt['popularity'] >= 50]
display(maiores_que_50)
# Out:
#                           id                   name      genre  \
# 2365  2R5iTxkCln6NLTw6l0kjWw    Happy Birthday Song      happy
# 2855  2F8GhUTkpV6FejsIRxDNB8          Indiana Jones     indian
# 1921  767Tv7BrZVK5B3mZEluODN             Funky Town       funk
# 1377  2cFGv8v5DcbJXHEdzouFne  Remember Me (Lullaby)     disney
# 5538  7fMrzJgBQSprNEV7iFI68u          Sleepy Clouds      sleep
# ...                      ...                    ...        ...
# 1065  2cmRpmO04TLaKPzmAzySYZ     Dance Yrself Clean      dance
# 1054  4LCzEYKPFcd2FCOmZdVDnM   Dance With The Devil      dance
# 4753  2URJ4lQUDWvCykwRKD6d8L         Rainy Day Path  rainy-day
# 1300  5jUA1njy3h6ynHLvPdEVHt          Disco Inferno      disco
# 4100  6lVO4RRaF6PZCo9ClhXy0A       Pagodeiro, Pt. 2     pagode
#
#                                                 artists  \
# 2365                                          CoComelon
# 2855                                         Yuno Miles
# ...

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# Visualização de Dados:
#
# Crie gráficos simples (como histogramas, barras) usando dados do DataFrame.
#
# Personalize a aparência dos gráficos usando parâmetros do pandas e matplotlib.

# %%
import matplotlib.pyplot as plt
spo_dt.hist()
plt.show()

# %%
spo_dt.plot()
# Out:
# <Axes: >

# %%
spo_dt.plot.scatter('popularity', 'duration_ms')
# Out:
# <Axes: xlabel='popularity', ylabel='duration_ms'>

# %% [markdown]
# -------------------------------------------------------------------------------

# %% [markdown]
# Tratamento de Dados Faltantes:
#
# Identifique e conte valores faltantes no DataFrame.
#
# Preencha valores faltantes com médias, medianas ou valores específicos.

# %% [markdown]
# --------------------------------------------------------------------

# %% [markdown]
# Concatenação e Mesclagem de DataFrames:
#
# Concatene dois DataFrames ao longo de linhas ou colunas.
#
# Mescle DataFrames usando chaves de junção.

# %% [markdown]
# ----------------------------------------------------------------------------

# %% [markdown]
# Leitura e Escrita de Arquivos:
#
# Leia dados de um arquivo CSV ou Excel para um DataFrame.
#
# Escreva um DataFrame de volta para um arquivo CSV ou Excel.

# %%
df = pd.DataFrame(spo_dt)

# %%
a_csv = df.to_csv('spo_novo', index=False)
